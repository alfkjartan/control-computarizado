# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import control.matlab as cm

# %%
wn = 1
w0 = np.sqrt( 2.0/(-3+np.sqrt(9 + 4*(30**2-9))) )
H = cm.tf([3], [1/w0**2, 3/w0, 3])

(mag, ph, W) = cm.bode(H)
# Out:
# <img src="data:image/png;base64,...">

# %%
np.sqrt((-3 + np.sqrt(9 + 4*(30**2 - 9)))/2)
# Out:
# 5.3279722472772804
